# %%
#funcionamiento del notebook
import nest_asyncio
nest_asyncio.apply()

# %%
from page_deep_scraper import page_deep_scraper


reity = await page_deep_scraper("https://reity.cl")
#tokenit = await page_deep_scraper("https://tokenit.cl")
#omosrentable = await page_analyzer("somosrentable.com")

# %%
x = reity["allInternalLinks"]
print(x)

# %%
from model_builder import page_deep_scraped_to_model
result = page_deep_scraped_to_model(reity)
print(result)
# Out:
# [{'url': 'https://reity.cl', 'links': {'head': [], 'header': [], 'main': ['https://reity.cl/regulacion', 'https://reity.cl/marketplace', 'https://reity.cl/blog', 'https://ayuda.reity.cl/es', 'https://reity.cl/signin', 'https://reity.cl/signup', 'https://youtube.com/watch?v=0RjzndEeGYU&t=600s', 'https://df.cl/df-mas/como-cuido-mis-lucas/conviene-comprar-una-parte-de-una-vivienda', 'https://emol.com/noticias/Tendencias/2023/12/18/1116081/tokenizacion-inmobiliaria-startup-reity.html', 'https://fintechile.org/noticias/reity-lanza-token-para-masificar-acceso-a-inversion-inmobiliaria', 'https://youtube.com/watch?v=fA9KNGjFUlI', 'https://apps.apple.com/cl/app/reity/id6468899299', 'https://play.google.com/store/apps/details?id=com.reity.app', 'https://reity.cl/blog/product-update-mercado-secundario-mejorado', 'https://reity.cl/blog/vamos-partiendo-el-programa-imagine-global-us-en-new-york-y-san-francisco', 'https://reity.cl/blog/reity-cmf-regulacion-cuatro-figuras-ley-fintec', 'https://ayuda.reity.cl/es/collections/7476943-preguntas-frecuentes', 'https://reity.notion.site/Trabaja-en-Reity-ac44b702f73445e48de22028cd8c2abc?pvs=4', 'https://reity.cl/terminos-y-condiciones', 'https://reity.cl/politica-privacidad', 'https://reity.nyc3.cdn.digitaloceanspaces.com/Contratos/Condiciones%20Generales%20y%20Especiales%20Reity%20', 'https://reity.cl/anexos', 'https://reity.buk.cl/cul_partner_complaint/tickets/new', 'https://linkedin.com/company/reitytoken', 'https://instagram.com/reity.token'], 'footer': ['https://apps.apple.com/cl/app/reity/id6468899299', 'https://play.google.com/store/apps/details?id=com.reity.app', 'https://reity.cl/regulacion', 'https://reity.cl/blog', 'https://reity.notion.site/Trabaja-en-Reity-ac44b702f73445e48de22028cd8c2abc?pvs=4', 'https://reity.cl/terminos-y-condiciones', 'https://reity.cl/politica-privacidad', 'https://reity.nyc3.cdn.digitaloceanspaces.com/Contratos/Condiciones%20Generales%20y%20Especiales%20Reity%20', 'https://reity.cl/anexos', 'https://reity.buk.cl/cul_partner_complaint/tickets/new', 'https://linkedin.com/company/reitytoken', 'https://instagram.com/reity.token']}, 'texts': {'head': [], 'header': [], 'main': ['Start of bodyStart End of bodyStart', '$', 'Nos estamos regulando ante la Comisión para el Mercado Financiero (CMF), y operamos bajo el régimen transitorio de la Ley Fintec.', 'Conoce más', '/$', 'Nos estamos regulando ante la CMF', 'Nos estamos regulando ante la Comisión para el Mercado Financiero (CMF).', 'Marketplace', 'Regulación', 'Blog', 'Ayuda', 'Ingresa', 'Invierte fácil', 'en', 'activos inmobiliarios', 'tokenizados', 'seguros', 'estables', 'Diversifica tu portafolio con inversiones inmobiliarias respaldadas por activos reales. Más estable que las acciones. Más rentable que depósitos a plazo.', 'Comienza a invertir', 'Invierte en activos de calibre institucional sin necesitar el traje 👔', 'Reity es una plataforma de', 'crowdfunding', 'donde puedes', 'invertir en instrumentos de financiamiento', 'con propiedades y acciones de Inmobiliarias como activo subyacente.', 'Accede a productos históricamente exclusivos', ', con mayor liquidez, transparencia y control.', 'Genera ingresos pasivos', 'Invierte el monto que quieras cuando quieras, 100% online desde tu celular o computador. Relájate y mira cómo tu dinero trabaja por ti.', 'Sin intermediarios', 'Sáltate el proceso de comprar una propiedad y ve directo a las ganancias. Sin notarías, burocracia o trámites complicados.', 'Tu inversión, protegida', 'Con el respaldo y experiencia de la inmobiliaria Norte Verde. Tu dinero está protegido por el valor tangible de los activos.', 'Diversifica tu portafolio con activos alternativos estables y rentables', 'Renta', 'Gana a diario una parte del arriendo neto de departamentos, mientras acumulas plusvalía en un plazo aproximado de 5 años.', 'Edificio Quinta Vista', 'Proyecto Borde Vivo', 'Socio Preferente', 'Gana una tasa fija en UF participando del financiamiento para desarrollo inmobiliario con garantí ...

# %%
print(result[3]["url"])
# Out:
# https://reity.cl/politica-privacidad

# %%
lista_pages = []
for page in reity["pages"]:
    lista_pages.append(page)
    

for page in lista_pages:
    print(page)
#    print(reity["pages"][page]["links"]["main"])

# %%
#Import lectura HTML
from utils.requestHTTP import fetch_html

#Import manejo de urls desde el HTML
from utils.urls_extractor_from_html import urls_extractor_from_html  
from utils.urls_utilities_cleaner import urls_utilities_cleaner
from utils.urls_format_from_domain import urls_format_from_domain

#import manejo de html
from utils.html_spliter_head_header_main_footer import html_spliter_head_header_main_footer

#import manejo de textos desde el html
from utils.text_extractor_from_html import text_extractor_from_html

# %%
#Lectura del HTML
link ="https://reental.co"
html = await fetch_html(link)
#print(html)

# %%
head_main_foot = html_spliter_head_header_main_footer(html)

# %%
head = head_main_foot["head"]
#print(head[:1000])
head_text = text_extractor_from_html(head)
head_urls = urls_extractor_from_html(head)
head_urls = urls_utilities_cleaner(head_urls)
head_urls = urls_format_from_domain(head_urls, link)

print("TEXTOS")
print("Cantidad de textos: " + str(len(head_text)))
print(head_text[:20])
print("URLs")
print("Cantidad de urls: " + str(len(head_urls)))
print(head_urls[:20])

# %%
header = head_main_foot["header"]
#print(header[:1000])
header_text = text_extractor_from_html(header)
header_urls = urls_extractor_from_html(header)
header_urls = urls_utilities_cleaner(header_urls)
header_urls = urls_format_from_domain(header_urls, link)

print("TEXTOS")
print("Cantidad de textos: " + str(len(header_text)))
print(header_text[:20])
print("URLs")
print("Cantidad de urls: " + str(len(header_urls)))
print(header_urls[:20])

# %%
main = head_main_foot["main"]
#print(main[:1000])
main_text = text_extractor_from_html(main)
main_urls = urls_extractor_from_html(main)
main_urls = urls_utilities_cleaner(main_urls)
main_urls = urls_format_from_domain(main_urls, link)

print("TEXTOS")
print("Cantidad de textos: " + str(len(main_text)))
print(main_text[:20])
print("URLs")
print("Cantidad de urls: " + str(len(main_urls)))
print(main_urls[:20])

# %%
footer = head_main_foot["footer"]
#print(footer[:1000])
footer_text = text_extractor_from_html(footer)
footer_urls = urls_extractor_from_html(footer)
footer_urls = urls_utilities_cleaner(footer_urls)
footer_urls = urls_format_from_domain(footer_urls, link)

print("TEXTOS")
print("Cantidad de textos: " + str(len(footer_text)))
print(footer_text[:20])
print("URLs")
print("Cantidad de urls: " + str(len(footer_urls)))
print(footer_urls[:20])
